# %% [markdown]
# # HCI RAG Evaluation Notebook
#
# This notebook is a lightweight exploration space for analyzing retrieval quality and generation quality.

# %%
from pathlib import Path
import pandas as pd

root = Path('..')
results = pd.read_csv(root / 'outputs' / 'results.csv')
results.head()
